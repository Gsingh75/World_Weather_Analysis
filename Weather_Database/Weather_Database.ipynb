# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print("City Count: " + str(len(cities)))
# Out:
# City Count: 771

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_keys

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_keys

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | maryville
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | lavrentiya
# Processing Record 5 of Set 1 | ancud
# Processing Record 6 of Set 1 | bairiki
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | axim
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | muncar
# Processing Record 12 of Set 1 | valky
# Processing Record 13 of Set 1 | vao
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | springbok
# Processing Record 16 of Set 1 | laguna
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | hambantota
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | margate
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 28 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 1 | kaya
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | penha
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | arcachon
# Processing Record 34 of Set 1 | fairbanks
# Processing Record 35 of Set 1 | the valley
# Processing Record 36 of Set 1 | san cristobal
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | ilhabela
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | ostersund
# Processing Record 42 of Set 1 | vila
# Processing Record 43 of Set 1 | raton
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | luderitz
# Processing Record 47 of Set 1 | alice springs
# Processing Record 48 of Set 1 | coihaique
# Processing Record 49 of Set 1 | yerbogachen
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | yining
# Processing Record 2 of Set 2 | ayyampettai
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | tiksi
# Processing Record 5 of Set 2 | itarema
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | ahipara
# Processing Record 9 of Set 2 | new norfolk
# Processing Record 10 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | kibre mengist
# Processing Record 13 of Set 2 | manggar
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | kavaratti
# Processing Record 17 of Set 2 | port hardy
# Processing Record 18 of Set 2 | sorland
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | airai
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | nushki
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | sarh
# Processing Record 25 of Set 2 | valparaiso
# Processing Record 26 of Set 2 | omboue
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | notodden
# Processing Record 32 of Set 2 | minab
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | kloulklubed
# Processing Record 35 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 2 | dindori
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | tallahassee
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 41 of Set 2 | klaksvik
# Processing Record 42 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | fukue
# Processing Record 45 of Set 2 | amursk
# Processing Record 46 of Set 2 | camargo
# Processing Record 47 of Set 2 | yar-sale
# Processing Record 48 of Set 2 | aksu
# Processing Record 49 of Set 2 | saldanha
# Processing Record 50 of Set 2 | sioux lookout
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | sonepur
# Processing Record 5 of Set 3 | banda aceh
# Processing Record 6 of Set 3 | punta arenas
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | pevek
# Processing Record 9 of Set 3 | veraval
# Processing Record 10 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 3 | toktogul
# Processing Record 12 of Set 3 | busselton
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | abu zabad
# Processing Record 15 of Set 3 | zyryanka
# Processing Record 16 of Set 3 | saint-philippe
# Processing Record 17 of Set 3 | miyako
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | san patricio
# Processing Record 20 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 3 | great bend
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | hay river
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | carutapera
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | vologda
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 3 | adrar
# Processing Record 30 of Set 3 | romitan
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | slonim
# Processing Record 35 of Set 3 | behbahan
# Processing Record 36 of Set 3 | bandarbeyla
# Processing Record 37 of Set 3 | senador jose porfirio
# Processing Record 38 of Set 3 | pisco
# Processing Record 39 of Set 3 | cabinda
# Processing Record 40 of Set 3 | mehamn
# Processing Record 41 of Set 3 | ambon
# Processing Record 42 of Set 3 | tongchuan
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | ngorongoro
# Processing Record 45 of Set 3 | port blair
# Processing Record 46 of Set 3 | babu
# Processing Record 47 of Set 3 | geraldton
# Processing Record 48 of Set 3 | shaunavon
# Processing Record 49 of Set 3 | atlacomulco
# Processing Record 50 of Set 3 | zhigansk
# Processing Record 1 of Set 4 | molina
# Processing Record 2 of Set 4 | leshukonskoye
# Processing Record 3 of Set 4 | okhotsk
# Processing Record 4 of Set 4 | ulagan
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | port keats
# Processing Record 7 of Set 4 | marawi
# Processing Record 8 of Set 4 | hwange
# Processing Record 9 of Set 4 | katsuura
# Processing Record 10 of Set 4 | carnarvon
# Processing Record 11 of Set 4 | srednekolymsk
# Processing Record 12 of Set 4 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 13 of Set 4 | rio grande
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | oil city
# Processing Record 16 of Set 4 | lata
# Processing Record 17 of Set 4 | rabat
# Processing Record 18 of Set 4 | san mateo ixtatan
# Processing Record 19 of Set 4 | det udom
# Processing Record 20 of Set 4 | sao miguel do iguacu
# Processing Record 21 of Set 4 | port-cartier
# Processing Record 22 of Set 4 | los llanos de aridane
# Processing Record 23 of Set 4 | aquin
# Processing Record 24 of Set 4 | cuenca
# Processing Record 25 of Set 4 | laishevo
# Processing Record 26 of Set 4 | bac lieu
# Processing Record 27 of Set 4 | san ramon
# Processing Record 28 of Set 4 | am timan
# Processing Record 29 of Set 4 | atar
# Processing Record 30 of Set 4 | kachug
# Processing Record 31 of Set 4 | cherskiy
# Processing Record 32 of Set 4 | tezu
# Processing Record 33 of Set 4 | castro
# Processing Record 34 of Set 4 | swan hill
# Processing Record 35 of Set 4 | kanel
# Processing Record 36 of Set 4 | waingapu
# Processing Record 37 of Set 4 | vilyuysk
# Processing Record 38 of Set 4 | yaan
# Processing Record 39 of Set 4 | chicama
# Processing Record 40 of Set 4 | san pedro
# Processing Record 41 of Set 4 | conceicao do araguaia
# Processing Record 42 of Set 4 | ugoofaaru
# Processing Record 43 of Set 4 | sobolevo
# Processing Record 44 of Set 4 | morros
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | salo
# Processing Record 47 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | fortuna
# Processing Record 50 of Set 4 | tibu
# Processing Record 1 of Set 5 | dhidhdhoo
# Processing Record 2 of Set 5 | aparecida do taboado
# Processing Record 3 of Set 5 | ventspils
# Processing Record 4 of Set 5 | meulaboh
# Processing Record 5 of Set 5 | constantine
# Processing Record 6 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 5 | najran
# Processing Record 8 of Set 5 | kruisfontein
# Processing Record 9 of Set 5 | hun
# Processing Record 10 of Set 5 | santa isabel
# Processing Record 11 of Set 5 | umm lajj
# Processing Record 12 of Set 5 | pontiac
# Processing Record 13 of Set 5 | saint-joseph
# Processing Record 14 of Set 5 | paamiut
# Processing Record 15 of Set 5 | masumbwe
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | ambilobe
# Processing Record 18 of Set 5 | asau
# Processing Record 19 of Set 5 | coruripe
# Processing Record 20 of Set 5 | bethel
# Processing Record 21 of Set 5 | natal
# Processing Record 22 of Set 5 | saurimo
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | marsh harbour
# Processing Record 25 of Set 5 | hastings
# Processing Record 26 of Set 5 | ribeira grande
# Processing Record 27 of Set 5 | aklavik
# Processing Record 28 of Set 5 | torbay
# Processing Record 29 of Set 5 | sinnamary
# Processing Record 30 of Set 5 | upata
# Processing Record 31 of Set 5 | kalmunai
# Processing Record 32 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 33 of Set 5 | goderich
# Processing Record 34 of Set 5 | usinsk
# Processing Record 35 of Set 5 | dulovo
# Processing Record 36 of Set 5 | casablanca
# Processing Record 37 of Set 5 | souillac
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | norman wells
# Processing Record 40 of Set 5 | prince albert
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 5 | port elizabeth
# Processing Record 43 of Set 5 | shuyskoye
# Processing Record 44 of Set 5 | acapulco
# Processing Record 45 of Set 5 | villa maria
# Processing Record 46 of Set 5 | berlevag
# Processing Record 47 of Set 5 | broken hill
# Processing Record 48 of Set 5 | ponazyrevo
# Processing Record 49 of Set 5 | tivaouane
# Processing Record 50 of Set 5 | punta cardon
# Processing Record 1 of Set 6 | marsabit
# Processing Record 2 of Set 6 | pyaozerskiy
# Processing Record 3 of Set 6 | llanes
# Processing Record 4 of Set 6 | chekhov
# Processing Record 5 of Set 6 | santa ana
# Processing Record 6 of Set 6 | serik
# Processing Record 7 of Set 6 | duz
# City not found. Skipping...
# Processing Record 8 of Set 6 | sylvan lake
# Processing Record 9 of Set 6 | sao miguel do araguaia
# Processing Record 10 of Set 6 | verkhnyaya toyma
# Processing Record 11 of Set 6 | bani walid
# Processing Record 12 of Set 6 | narsaq
# Processing Record 13 of Set 6 | twistringen
# Processing Record 14 of Set 6 | pacific grove
# Processing Record 15 of Set 6 | tobol
# Processing Record 16 of Set 6 | wellington
# Processing Record 17 of Set 6 | taxisco
# Processing Record 18 of Set 6 | barcelos
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | plettenberg bay
# Processing Record 21 of Set 6 | chara
# Processing Record 22 of Set 6 | kaeo
# Processing Record 23 of Set 6 | upernavik
# Processing Record 24 of Set 6 | aswan
# Processing Record 25 of Set 6 | esperance
# Processing Record 26 of Set 6 | kalamazoo
# Processing Record 27 of Set 6 | pimentel
# Processing Record 28 of Set 6 | talnakh
# Processing Record 29 of Set 6 | portland
# Processing Record 30 of Set 6 | caravelas
# Processing Record 31 of Set 6 | sanmenxia
# Processing Record 32 of Set 6 | saint-augustin
# Processing Record 33 of Set 6 | tevaitoa
# Processing Record 34 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 35 of Set 6 | caluquembe
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | munster
# Processing Record 38 of Set 6 | hamilton
# Processing Record 39 of Set 6 | vinukonda
# Processing Record 40 of Set 6 | catuday
# Processing Record 41 of Set 6 | huntsville
# Processing Record 42 of Set 6 | moyale
# Processing Record 43 of Set 6 | ouallam
# Processing Record 44 of Set 6 | rocha
# Processing Record 45 of Set 6 | mahibadhoo
# Processing Record 46 of Set 6 | isangel
# Processing Record 47 of Set 6 | kidal
# Processing Record 48 of Set 6 | qaqortoq
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | palana
# Processing Record 1 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | alta floresta
# Processing Record 4 of Set 7 | warrington
# Processing Record 5 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 7 | marathokambos
# City not found. Skipping...
# Processing Record 7 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 7 | palembang
# Processing Record 9 of Set 7 | hailar
# Processing Record 10 of Set 7 | charters towers
# Processing Record 11 of Set 7 | chimay
# Processing Record 12 of Set 7 | geilo
# Processing Record 13 of Set 7 | jinchang
# Processing Record 14 of Set 7 | sao felix do xingu
# Processing Record 15 of Set 7 | chumikan
# Processing Record 16 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 7 | kahului
# Processing Record 18 of Set 7 | bull savanna
# Processing Record 19 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 7 | raudeberg
# Processing Record 21 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 7 | brae
# Processing Record 23 of Set 7 | eureka
# Processing Record 24 of Set 7 | mitu
# Processing Record 25 of Set 7 | port macquarie
# Processing Record 26 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 7 | suez
# Processing Record 28 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 7 | uruguaiana
# Processing Record 30 of Set 7 | broome
# Processing Record 31 of Set 7 | tazovskiy
# Processing Record 32 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 7 | tura
# Processing Record 34 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 35 of Set 7 | turukhansk
# Processing Record 36 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 37 of Set 7 | talcahuano
# Processing Record 38 of Set 7 | bathsheba
# Processing Record 39 of Set 7 | general roca
# Processing Record 40 of Set 7 | sovetskiy
# Processing Record 41 of Set 7 | estelle
# Processing Record 42 of Set 7 | phan thiet
# Processing Record 43 of Set 7 | belinskiy
# Processing Record 44 of Set 7 | buin
# Processing Record 45 of Set 7 | garowe
# Processing Record 46 of Set 7 | bueno brandao
# Processing Record 47 of Set 7 | merauke
# Processing Record 48 of Set 7 | ereymentau
# Processing Record 49 of Set 7 | pizarro
# Processing Record 50 of Set 7 | bahia honda
# Processing Record 1 of Set 8 | changzhou
# Processing Record 2 of Set 8 | manzhouli
# Processing Record 3 of Set 8 | alugan
# Processing Record 4 of Set 8 | nantucket
# Processing Record 5 of Set 8 | honolulu
# Processing Record 6 of Set 8 | vardo
# Processing Record 7 of Set 8 | hualmay
# Processing Record 8 of Set 8 | gogrial
# Processing Record 9 of Set 8 | ornskoldsvik
# Processing Record 10 of Set 8 | abnub
# Processing Record 11 of Set 8 | zaraza
# Processing Record 12 of Set 8 | luganville
# Processing Record 13 of Set 8 | dingle
# Processing Record 14 of Set 8 | roald
# Processing Record 15 of Set 8 | illapel
# Processing Record 16 of Set 8 | santa cruz
# Processing Record 17 of Set 8 | kyren
# Processing Record 18 of Set 8 | sergiyevsk
# Processing Record 19 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 8 | nueve de julio
# Processing Record 21 of Set 8 | westport
# Processing Record 22 of Set 8 | taoudenni
# Processing Record 23 of Set 8 | hami
# Processing Record 24 of Set 8 | montorio al vomano
# Processing Record 25 of Set 8 | manaus
# Processing Record 26 of Set 8 | nago
# Processing Record 27 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 28 of Set 8 | tilichiki
# Processing Record 29 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 8 | racine
# Processing Record 31 of Set 8 | stege
# Processing Record 32 of Set 8 | nadym
# Processing Record 33 of Set 8 | komsomolskiy
# Processing Record 34 of Set 8 | birao
# Processing Record 35 of Set 8 | eenhana
# Processing Record 36 of Set 8 | bosaso
# Processing Record 37 of Set 8 | fort nelson
# Processing Record 38 of Set 8 | springfield
# Processing Record 39 of Set 8 | codrington
# Processing Record 40 of Set 8 | morant bay
# Processing Record 41 of Set 8 | guarapari
# Processing Record 42 of Set 8 | alofi
# Processing Record 43 of Set 8 | vastervik
# City not found. Skipping...
# Processing Record 44 of Set 8 | archidona
# Processing Record 45 of Set 8 | neryungri
# Processing Record 46 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 47 of Set 8 | gidole
# Processing Record 48 of Set 8 | ust-uda
# Processing Record 49 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 50 of Set 8 | mangai
# Processing Record 1 of Set 9 | nome
# Processing Record 2 of Set 9 | krasnoselkup
# Processing Record 3 of Set 9 | lompoc
# Processing Record 4 of Set 9 | teluk nibung
# Processing Record 5 of Set 9 | bonthe
# Processing Record 6 of Set 9 | wesselsbron
# Processing Record 7 of Set 9 | saint george
# Processing Record 8 of Set 9 | peace river
# Processing Record 9 of Set 9 | mnogovershinnyy
# Processing Record 10 of Set 9 | yen bai
# Processing Record 11 of Set 9 | svetlogorsk
# Processing Record 12 of Set 9 | mount gambier
# Processing Record 13 of Set 9 | beyneu
# Processing Record 14 of Set 9 | guebwiller
# Processing Record 15 of Set 9 | urumqi
# Processing Record 16 of Set 9 | winnemucca
# Processing Record 17 of Set 9 | oranjemund
# Processing Record 18 of Set 9 | rovaniemi
# Processing Record 19 of Set 9 | batagay
# Processing Record 20 of Set 9 | egvekinot
# Processing Record 21 of Set 9 | vanavara
# Processing Record 22 of Set 9 | sturgis
# Processing Record 23 of Set 9 | nakamura
# Processing Record 24 of Set 9 | waddan
# Processing Record 25 of Set 9 | jardim de piranhas
# Processing Record 26 of Set 9 | pirawa
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | flinders
# Processing Record 29 of Set 9 | nyurba
# Processing Record 30 of Set 9 | puerto colombia
# Processing Record 31 of Set 9 | cayambe
# Processing Record 32 of Set 9 | lagoa
# Processing Record 33 of Set 9 | longyearbyen
# Processing Record 34 of Set 9 | tiznit
# Processing Record 35 of Set 9 | chalus
# Processing Record 36 of Set 9 | san lawrenz
# Processing Record 37 of Set 9 | camacha
# Processing Record 38 of Set 9 | pandaan
# Processing Record 39 of Set 9 | la ligua
# Processing Record 40 of Set 9 | bilma
# Processing Record 41 of Set 9 | mopti
# Processing Record 42 of Set 9 | green valley
# Processing Record 43 of Set 9 | sao filipe
# Processing Record 44 of Set 9 | ati
# Processing Record 45 of Set 9 | shunyi
# Processing Record 46 of Set 9 | erzurum
# Processing Record 47 of Set 9 | mudyuga
# City not found. Skipping...
# Processing Record 48 of Set 9 | palauig
# Processing Record 49 of Set 9 | bubaque
# Processing Record 50 of Set 9 | tautira
# Processing Record 1 of Set 10 | tombouctou
# Processing Record 2 of Set 10 | karaton
# Processing Record 3 of Set 10 | shihezi
# Processing Record 4 of Set 10 | grand gaube
# Processing Record 5 of Set 10 | sakakah
# Processing Record 6 of Set 10 | mamallapuram
# Processing Record 7 of Set 10 | havelock
# Processing Record 8 of Set 10 | poum
# Processing Record 9 of Set 10 | vestmannaeyjar
# Processing Record 10 of Set 10 | bouza
# Processing Record 11 of Set 10 | buraydah
# Processing Record 12 of Set 10 | pitimbu
# Processing Record 13 of Set 10 | korgen
# Processing Record 14 of Set 10 | khairagarh
# Processing Record 15 of Set 10 | saint cloud
# Processing Record 16 of Set 10 | rochegda
# Processing Record 17 of Set 10 | wanning
# Processing Record 18 of Set 10 | cidreira
# Processing Record 19 of Set 10 | cap malheureux
# Processing Record 20 of Set 10 | bolobo
# Processing Record 21 of Set 10 | goure
# Processing Record 22 of Set 10 | oktyabrskiy
# Processing Record 23 of Set 10 | necochea
# Processing Record 24 of Set 10 | pathein
# Processing Record 25 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 10 | portel
# Processing Record 27 of Set 10 | beloha
# Processing Record 28 of Set 10 | bud
# Processing Record 29 of Set 10 | pakxan
# Processing Record 30 of Set 10 | partur
# Processing Record 31 of Set 10 | tabukiniberu
# City not found. Skipping...
# Processing Record 32 of Set 10 | ojinaga
# Processing Record 33 of Set 10 | remedios
# Processing Record 34 of Set 10 | rorvik
# Processing Record 35 of Set 10 | vila velha
# Processing Record 36 of Set 10 | awbari
# Processing Record 37 of Set 10 | mayari
# City not found. Skipping...
# Processing Record 38 of Set 10 | atherton
# Processing Record 39 of Set 10 | mori
# Processing Record 40 of Set 10 | becerril
# Processing Record 41 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 10 | hobyo
# Processing Record 43 of Set 10 | lazarev
# Processing Record 44 of Set 10 | grindavik
# Processing Record 45 of Set 10 | olbia
# Processing Record 46 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 10 | muhos
# Processing Record 48 of Set 10 | rockland
# Processing Record 49 of Set 10 | bonoua
# Processing Record 50 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 1 of Set 11 | evans
# Processing Record 2 of Set 11 | shurugwi
# Processing Record 3 of Set 11 | kerema
# Processing Record 4 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 5 of Set 11 | portalegre
# Processing Record 6 of Set 11 | aykhal
# Processing Record 7 of Set 11 | tongsa
# City not found. Skipping...
# Processing Record 8 of Set 11 | pundaguitan
# Processing Record 9 of Set 11 | santa catarina de tepehuanes
# Processing Record 10 of Set 11 | miri
# Processing Record 11 of Set 11 | nokaneng
# Processing Record 12 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 11 | coahuayana
# Processing Record 14 of Set 11 | nevsehir
# Processing Record 15 of Set 11 | dromolaxia
# Processing Record 16 of Set 11 | sitka
# Processing Record 17 of Set 11 | golyshmanovo
# Processing Record 18 of Set 11 | belmonte
# Processing Record 19 of Set 11 | piacabucu
# Processing Record 20 of Set 11 | kushiro
# Processing Record 21 of Set 11 | tarko-sale
# Processing Record 22 of Set 11 | ust-omchug
# Processing Record 23 of Set 11 | budogoshch
# Processing Record 24 of Set 11 | bad langensalza
# Processing Record 25 of Set 11 | ballina
# Processing Record 26 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 27 of Set 11 | pila
# Processing Record 28 of Set 11 | muros
# Processing Record 29 of Set 11 | mount isa
# Processing Record 30 of Set 11 | ko samui
# Processing Record 31 of Set 11 | bengkulu
# Processing Record 32 of Set 11 | hofn
# Processing Record 33 of Set 11 | aloleng
# Processing Record 34 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 11 | chimore
# Processing Record 36 of Set 11 | ribas do rio pardo
# Processing Record 37 of Set 11 | parana
# Processing Record 38 of Set 11 | kiama
# Processing Record 39 of Set 11 | quelimane
# Processing Record 40 of Set 11 | entebbe
# Processing Record 41 of Set 11 | misratah
# Processing Record 42 of Set 11 | trairi
# Processing Record 43 of Set 11 | baykit
# Processing Record 44 of Set 11 | whitehorse
# Processing Record 45 of Set 11 | takaka
# Processing Record 46 of Set 11 | san andres
# Processing Record 47 of Set 11 | skjervoy
# Processing Record 48 of Set 11 | shrewsbury
# Processing Record 49 of Set 11 | buchmany
# Processing Record 50 of Set 11 | nemuro
# Processing Record 1 of Set 12 | padang
# Processing Record 2 of Set 12 | mahabad
# Processing Record 3 of Set 12 | gambiran
# Processing Record 4 of Set 12 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 5 of Set 12 | east millcreek
# Processing Record 6 of Set 12 | nhulunbuy
# Processing Record 7 of Set 12 | cristalina
# Processing Record 8 of Set 12 | esna
# Processing Record 9 of Set 12 | campbellsville
# Processing Record 10 of Set 12 | yarim
# Processing Record 11 of Set 12 | mayo
# Processing Record 12 of Set 12 | dikson
# Processing Record 13 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 12 | matai
# Processing Record 15 of Set 12 | warman
# Processing Record 16 of Set 12 | masvingo
# Processing Record 17 of Set 12 | zhanaozen
# Processing Record 18 of Set 12 | waipawa
# Processing Record 19 of Set 12 | cockburn town
# Processing Record 20 of Set 12 | havre-saint-pierre
# Processing Record 21 of Set 12 | lubao
# Processing Record 22 of Set 12 | salalah
# Processing Record 23 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 24 of Set 12 | shimoda
# Processing Record 25 of Set 12 | kolokani
# Processing Record 26 of Set 12 | aasiaat
# Processing Record 27 of Set 12 | loum
# Processing Record 28 of Set 12 | beatrice
# Processing Record 29 of Set 12 | mahebourg
# Processing Record 30 of Set 12 | santa fe
# Processing Record 31 of Set 12 | iisalmi
# Processing Record 32 of Set 12 | rzhev
# Processing Record 33 of Set 12 | divnogorsk
# Processing Record 34 of Set 12 | novyy urengoy
# Processing Record 35 of Set 12 | yenagoa
# Processing Record 36 of Set 12 | ojhar
# Processing Record 37 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 12 | madison
# Processing Record 39 of Set 12 | sistranda
# Processing Record 40 of Set 12 | yenangyaung
# Processing Record 41 of Set 12 | west bend
# Processing Record 42 of Set 12 | gornopravdinsk
# Processing Record 43 of Set 12 | mahon
# Processing Record 44 of Set 12 | carlagan
# Processing Record 45 of Set 12 | san quintin
# Processing Record 46 of Set 12 | channel-port aux basques
# Processing Record 47 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 12 | mgandu
# Processing Record 49 of Set 12 | lamar
# Processing Record 50 of Set 12 | barsovo
# Processing Record 1 of Set 13 | vidim
# Processing Record 2 of Set 13 | koslan
# Processing Record 3 of Set 13 | champerico
# Processing Record 4 of Set 13 | khash
# Processing Record 5 of Set 13 | gat
# Processing Record 6 of Set 13 | worland
# Processing Record 7 of Set 13 | la ronge
# Processing Record 8 of Set 13 | jiuquan
# Processing Record 9 of Set 13 | baleshwar
# Processing Record 10 of Set 13 | hamadan
# Processing Record 11 of Set 13 | haines junction
# Processing Record 12 of Set 13 | krutinka
# Processing Record 13 of Set 13 | ketchikan
# Processing Record 14 of Set 13 | faanui
# Processing Record 15 of Set 13 | safranbolu
# Processing Record 16 of Set 13 | pokhara
# Processing Record 17 of Set 13 | isoka
# Processing Record 18 of Set 13 | goksun
# Processing Record 19 of Set 13 | mattawa
# Processing Record 20 of Set 13 | harper
# Processing Record 21 of Set 13 | panormos
# Processing Record 22 of Set 13 | dire dawa
# Processing Record 23 of Set 13 | tabas
# Processing Record 24 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 25 of Set 13 | lichinga
# Processing Record 26 of Set 13 | rongcheng
# Processing Record 27 of Set 13 | tiarei
# Processing Record 28 of Set 13 | redmond
# Processing Record 29 of Set 13 | basco
# Processing Record 30 of Set 13 | tucupita
# Processing Record 31 of Set 13 | bontang
# Processing Record 32 of Set 13 | celestun
# Processing Record 33 of Set 13 | shingu
# Processing Record 34 of Set 13 | oistins
# Processing Record 35 of Set 13 | moyobamba
# Processing Record 36 of Set 13 | sur
# Processing Record 37 of Set 13 | oktyabrskoye
# Processing Record 38 of Set 13 | smithers
# Processing Record 39 of Set 13 | cravo norte
# Processing Record 40 of Set 13 | gaogou
# Processing Record 41 of Set 13 | naze
# Processing Record 42 of Set 13 | taft
# Processing Record 43 of Set 13 | belaya gora
# Processing Record 44 of Set 13 | koumac
# Processing Record 45 of Set 13 | turayf
# Processing Record 46 of Set 13 | iralaya
# Processing Record 47 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 13 | ostrovnoy
# Processing Record 49 of Set 13 | stromness
# Processing Record 50 of Set 13 | malakal
# Processing Record 1 of Set 14 | tabou
# Processing Record 2 of Set 14 | teacapan
# Processing Record 3 of Set 14 | twin falls
# Processing Record 4 of Set 14 | port augusta
# Processing Record 5 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 14 | bar harbor
# Processing Record 7 of Set 14 | grafton
# Processing Record 8 of Set 14 | vila franca do campo
# Processing Record 9 of Set 14 | stavern
# Processing Record 10 of Set 14 | oksfjord
# Processing Record 11 of Set 14 | gaoua
# Processing Record 12 of Set 14 | shelburne
# Processing Record 13 of Set 14 | fushun
# Processing Record 14 of Set 14 | taurage
# Processing Record 15 of Set 14 | college
# Processing Record 16 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 14 | evensk
# Processing Record 18 of Set 14 | nanchang
# Processing Record 19 of Set 14 | laredo
# Processing Record 20 of Set 14 | uray
# Processing Record 21 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 14 | snihurivka
# Processing Record 23 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 24 of Set 14 | marti
# Processing Record 25 of Set 14 | santa maria
# Processing Record 26 of Set 14 | shiraz
# Processing Record 27 of Set 14 | solano
# Processing Record 28 of Set 14 | hasaki
# Processing Record 29 of Set 14 | menongue
# Processing Record 30 of Set 14 | tera
# Processing Record 31 of Set 14 | neiafu
# Processing Record 32 of Set 14 | yumbing
# Processing Record 33 of Set 14 | esmeraldas
# Processing Record 34 of Set 14 | gondanglegi
# Processing Record 35 of Set 14 | bertoua
# Processing Record 36 of Set 14 | gilgit
# Processing Record 37 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 14 | yulara
# Processing Record 39 of Set 14 | kawalu
# Processing Record 40 of Set 14 | port hedland
# Processing Record 41 of Set 14 | cayenne
# Processing Record 42 of Set 14 | kalabo
# Processing Record 43 of Set 14 | thinadhoo
# Processing Record 44 of Set 14 | kolomna
# Processing Record 45 of Set 14 | nicoya
# Processing Record 46 of Set 14 | shubarkuduk
# Processing Record 47 of Set 14 | amlagora
# Processing Record 48 of Set 14 | kibala
# Processing Record 49 of Set 14 | batamshinskiy
# Processing Record 50 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 1 of Set 15 | sanok
# Processing Record 2 of Set 15 | elizabeth city
# Processing Record 3 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 4 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 15 | takayama
# Processing Record 6 of Set 15 | terenos
# Processing Record 7 of Set 15 | general pico
# Processing Record 8 of Set 15 | praia
# Processing Record 9 of Set 15 | warmbad
# Processing Record 10 of Set 15 | lakes entrance
# Processing Record 11 of Set 15 | whyalla
# Processing Record 12 of Set 15 | svetlaya
# Processing Record 13 of Set 15 | oxapampa
# Processing Record 14 of Set 15 | kokoda
# Processing Record 15 of Set 15 | urdoma
# Processing Record 16 of Set 15 | katherine
# Processing Record 17 of Set 15 | contamana
# Processing Record 18 of Set 15 | formosa
# Processing Record 19 of Set 15 | elat
# Processing Record 20 of Set 15 | moranbah
# Processing Record 21 of Set 15 | panama city
# Processing Record 22 of Set 15 | venice
# Processing Record 23 of Set 15 | razole
# Processing Record 24 of Set 15 | ye
# City not found. Skipping...
# Processing Record 25 of Set 15 | sainte-maxime
# Processing Record 26 of Set 15 | invermere
# Processing Record 27 of Set 15 | ceyranbatan
# Processing Record 28 of Set 15 | mbacke
# City not found. Skipping...
# Processing Record 29 of Set 15 | shaoyang
# Processing Record 30 of Set 15 | luwuk
# Processing Record 31 of Set 15 | langxiang
# Processing Record 32 of Set 15 | dunedin
# Processing Record 33 of Set 15 | panzhihua
# Processing Record 34 of Set 15 | biak
# Processing Record 35 of Set 15 | lincoln
# Processing Record 36 of Set 15 | kungurtug
# Processing Record 37 of Set 15 | villarrica
# Processing Record 38 of Set 15 | burica
# City not found. Skipping...
# Processing Record 39 of Set 15 | ngunguru
# Processing Record 40 of Set 15 | arlit
# Processing Record 41 of Set 15 | hornepayne
# Processing Record 42 of Set 15 | surgut
# Processing Record 43 of Set 15 | rio gallegos
# Processing Record 44 of Set 15 | iringa
# Processing Record 45 of Set 15 | muroto
# Processing Record 46 of Set 15 | tamandare
# Processing Record 47 of Set 15 | indramayu
# Processing Record 48 of Set 15 | valmiera
# Processing Record 49 of Set 15 | lubin
# Processing Record 50 of Set 15 | antsohihy
# Processing Record 1 of Set 16 | sambava
# Processing Record 2 of Set 16 | morondava
# Processing Record 3 of Set 16 | pereleshino
# Processing Record 4 of Set 16 | lerwick
# Processing Record 5 of Set 16 | nacunday
# City not found. Skipping...
# Processing Record 6 of Set 16 | samarai
# Processing Record 7 of Set 16 | akhtubinsk
# Processing Record 8 of Set 16 | kajiado
# Processing Record 9 of Set 16 | pangnirtung
# Processing Record 10 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 16 | tonota
# Processing Record 12 of Set 16 | roma
# Processing Record 13 of Set 16 | anadyr
# Processing Record 14 of Set 16 | auki
# Processing Record 15 of Set 16 | sabang
# Processing Record 16 of Set 16 | athens
# Processing Record 17 of Set 16 | half moon bay
# Processing Record 18 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 16 | rurrenabaque
# Processing Record 20 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 16 | leon valley
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Maryville  35.7565  -83.9705     56.25        92          75
# 1   Tuktoyaktuk  69.4541 -133.0374      3.20        92         100
# 2    Butaritari   3.0707  172.7902     81.43        79          66
# 3    Lavrentiya  65.5833 -171.0000    -22.07        93          16
# 4         Ancud -41.8697  -73.8203     53.17        90          98
# 5       Bairiki   1.3292  172.9752     80.60        94          75
# 6   Clyde River  70.4692  -68.5914    -18.17        76           0
# 7          Axim   4.8699   -2.2405     78.22        83          47
# 8          Hilo  19.7297 -155.0900     73.26        90         100
# 9  Ponta Do Sol  32.6667  -17.1000     61.72        69          70
#
#    Wind Speed Country          Current Description
# 0        6.91      US                broken clouds
# 1       10.36      CA                   light snow
# 2       21.39      KI                   light rain
# 3        9.37      RU                   few clouds
# 4        2.68      CL              overcast clouds
# 5        6.91      KI  light intensity shower rain
# 6       14.97      CA                    clear sky
# 7        4.92      GH                   light rain
# 8        5.01      US              overcast clouds
# 9        8.77      PT                broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Maryville      US  35.7565  -83.9705     56.25        92          75
# 1   Tuktoyaktuk      CA  69.4541 -133.0374      3.20        92         100
# 2    Butaritari      KI   3.0707  172.7902     81.43        79          66
# 3    Lavrentiya      RU  65.5833 -171.0000    -22.07        93          16
# 4         Ancud      CL -41.8697  -73.8203     53.17        90          98
# 5       Bairiki      KI   1.3292  172.9752     80.60        94          75
# 6   Clyde River      CA  70.4692  -68.5914    -18.17        76           0
# 7          Axim      GH   4.8699   -2.2405     78.22        83          47
# 8          Hilo      US  19.7297 -155.0900     73.26        90         100
# 9  Ponta Do Sol      PT  32.6667  -17.1000     61.72        69          70
#
#    Wind Speed          Current Description
# 0        6.91                broken clouds
# 1       10.36                   light snow
# 2       21.39                   light rain
# 3        9.37                   few clouds
# 4        2.68              overcast clouds
# 5        6.91  light intensity shower rain
# 6       14.97                    clear sky
# 7        4.92                   light rain
# 8        5.01              overcast clouds
# 9        8.77                broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
